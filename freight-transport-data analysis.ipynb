# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
bxl_5 = pd.read_csv("/belgium-obu/Bxl_5_2021.csv")
bxl_5.columns = ['datetime','street_id','count','vel']
and_5 = pd.read_csv("/belgium-obu/Anderlecht_5_2021.csv")
and_5.columns = ['datetime','street_id','count','vel']
bel_5 = pd.read_csv("/belgium-obu/Bel_5_2021.csv")
bel_5.columns = ['datetime','street_id','count','vel']
bxl_15 = pd.read_csv("/belgium-obu/Bxl_15_2021.csv")
bxl_15.columns = ['datetime','street_id','count','vel']
and_15 = pd.read_csv("/belgium-obu/Anderlecht_15_2021.csv")
and_15.columns = ['datetime','street_id','count','vel']
bel_15 = pd.read_csv("/belgium-obu/Bel_15_2021.csv")
bel_15.columns = ['datetime','street_id','count','vel']
bxl_30 = pd.read_csv("/belgium-obu/Bxl_30_2021.csv")
bxl_30.columns = ['datetime','street_id','count','vel']
and_30 = pd.read_csv("/belgium-obu/Anderlecht_30_2021.csv")
and_30.columns = ['datetime','street_id','count','vel']
bel_30 = pd.read_csv("/belgium-obu/Bel_30_2021.csv")
bel_30.columns = ['datetime','street_id','count','vel']

# %%
bxl_5['time_taken(mins)'] = 5
bel_5['time_taken(mins)'] = 5
and_5['time_taken(mins)'] = 5
bxl_15['time_taken(mins)'] = 15
bel_15['time_taken(mins)'] = 15
and_15['time_taken(mins)'] = 15
bxl_30['time_taken(mins)'] = 30
bel_30['time_taken(mins)'] = 30
and_30['time_taken(mins)'] = 30

# %%
bxl_5["datetime"]= pd.to_datetime(bxl_5["datetime"])

# %%
bxl_5["date"]= pd.to_datetime(bxl_5["datetime"]).dt.date
bxl_5["month"]= pd.to_datetime(bxl_5["datetime"]).dt.month
bxl_5["week"]= pd.to_datetime(bxl_5["datetime"]).dt.weekday
bxl_5["time"]= pd.to_datetime(bxl_5["datetime"]).dt.time

# %%
bxl_5 = bxl_5.sort_values(by="datetime")
bxl_5
# Out:
#                    datetime    street_id  count        vel  time_taken(mins)  \
# 58796   2021-03-13 11:35:00  2989.000000      1  45.000000                 5
# 553006  2021-03-13 11:35:00  4127.000000      1  79.000000                 5
# 1925125 2021-03-13 11:35:00  4388.000000      1  41.000000                 5
# 61827   2021-03-13 11:35:00   785.000000      3  39.666667                 5
# 1371367 2021-03-13 11:35:00   551.000000      1  36.000000                 5
# ...                     ...          ...    ...        ...               ...
# 2177369                 NaT    54.809524      0   7.000000                 5
# 2177370                 NaT    39.865741      0  18.000000                 5
# 2177371                 NaT     2.808926      0   0.000000                 5
# 2177372                 NaT    67.789474      0  19.000000                 5
# 2177373                 NaT    40.753968      0  21.000000                 5
#
#                date  month  week      time
# ...

# %%
bxl_5.describe()
# Out:
#           street_id         count           vel  time_taken(mins)  \
# count  2.180823e+06  2.180823e+06  2.180823e+06         2180823.0
# mean   2.251564e+03  1.230084e+00  2.790836e+01               5.0
# std    1.288271e+03  7.312490e-01  2.319457e+01               0.0
# min    0.000000e+00  0.000000e+00  0.000000e+00               5.0
# 25%    1.213000e+03  1.000000e+00  1.000000e+01               5.0
# 50%    2.228000e+03  1.000000e+00  2.500000e+01               5.0
# 75%    3.322000e+03  1.000000e+00  4.000000e+01               5.0
# max    4.539000e+03  2.100000e+01  2.520000e+02               5.0
#
#               month          week
# count  2.156506e+06  2.156506e+06
# mean   4.371877e+00  2.284966e+00
# std    9.311782e-01  1.563908e+00
# min    3.000000e+00  0.000000e+00
# 25%    4.000000e+00  1.000000e+00
# 50%    4.000000e+00  2.000000e+00
# 75%    5.000000e+00  4.000000e+00
# max    6.000000e+00  6.000000e+00

# %%
print( 'the frequency of zeros in vel column is', (bxl_5['vel']==0).sum() )
print( 'the frequency of zeros in count column is', (bxl_5['count']==0).sum() )
print( 'the frequency of zeros in streetid column is', (bxl_5['street_id']==0).sum() )
# Out:
# the frequency of zeros in vel column is 375225
# the frequency of zeros in count column is 24317
# the frequency of zeros in streetid column is 112

# %%
percent_missing = bxl_5.isnull().sum() * 100 / len(bxl_5)
percent_missing
# Out:
# datetime            1.115038
# street_id           0.000000
# count               0.000000
# vel                 0.000000
# time_taken(mins)    0.000000
# date                1.115038
# month               1.115038
# week                1.115038
# time                1.115038
# dtype: float64

# %%
bxl_5.dropna(inplace = True)
bxl_5.isnull().sum()
# Out:
# datetime            0
# street_id           0
# count               0
# vel                 0
# time_taken(mins)    0
# date                0
# month               0
# week                0
# time                0
# dtype: int64

# %%
bxl_5.set_index("datetime", inplace = True)

# %%
bxl_5.head(3)
# Out:
#                      street_id  count   vel  time_taken(mins)        date  \
# datetime
# 2021-03-13 11:35:00     2989.0      1  45.0                 5  2021-03-13
# 2021-03-13 11:35:00     4127.0      1  79.0                 5  2021-03-13
# 2021-03-13 11:35:00     4388.0      1  41.0                 5  2021-03-13
#
#                      month  week      time
# datetime
# 2021-03-13 11:35:00    3.0   5.0  11:35:00
# 2021-03-13 11:35:00    3.0   5.0  11:35:00
# 2021-03-13 11:35:00    3.0   5.0  11:35:00

# %%
from matplotlib import pyplot as plt
from pylab import rcParams
from statsmodels.tsa.seasonal import seasonal_decompose
rcParams['figure.figsize'] = 14, 8
plt.figure(num=None, figsize=(30, 20), dpi=80, facecolor='w', edgecolor='k')


plt.figure(num=None, figsize=(30, 20), dpi=80, facecolor='w', edgecolor='k')

series_count = bxl_5['count']
result_ct_add = seasonal_decompose(series_count, model='additive', period=4)
result_ct_add.plot()
plt.show()

# %%
from matplotlib import pyplot as plt
from pylab import rcParams
from statsmodels.tsa.seasonal import seasonal_decompose
rcParams['figure.figsize'] = 14, 8
plt.figure(num=None, figsize=(30, 20), dpi=80, facecolor='w', edgecolor='k')


plt.figure(num=None, figsize=(30, 20), dpi=80, facecolor='w', edgecolor='k')

series_count = bxl_5['vel']
result_vl_add = seasonal_decompose(series_count, model='additive', period=4)
result_vl_add.plot()
plt.show()

# %%
from pylab import rcParams
from sklearn.linear_model import LinearRegression

fig = plt.figure(figsize=(15, 7))
layout = (3, 2)
pm_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
mv_ax = plt.subplot2grid(layout, (1, 0), colspan=2)
fit_ax = plt.subplot2grid(layout, (2, 0), colspan=2)

pm_ax.plot(result_ct_add.trend)
pm_ax.set_title("Automatic decomposed trend")

mm = bxl_5['count'].rolling(12).mean()
mv_ax.plot(mm)
mv_ax.set_title("Moving average 12 steps")


X = [i for i in range(0, len(bxl_5['count']))]
X = np.reshape(X, (len(X), 1))
y = bxl_5['count'].values
model = LinearRegression()
model.fit(X, y)
# calculate trend
trend = model.predict(X)
fit_ax.plot(trend)
fit_ax.set_title("Trend fitted by linear regression")

plt.tight_layout()

# %%
from pylab import rcParams
from sklearn.linear_model import LinearRegression

fig = plt.figure(figsize=(15, 7))
layout = (3, 2)
pm_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
mv_ax = plt.subplot2grid(layout, (1, 0), colspan=2)
fit_ax = plt.subplot2grid(layout, (2, 0), colspan=2)

pm_ax.plot(result_vl_add.trend)
pm_ax.set_title("Automatic decomposed trend vel")

mm = bxl_5['vel'].rolling(12).mean()
mv_ax.plot(mm)
mv_ax.set_title("Moving average 12 steps")


X_vel = [i for i in range(0, len(bxl_5['vel']))]
X_vel = np.reshape(X, (len(X), 1))
y_vel = bxl_5['vel'].values
model_vel = LinearRegression()
model_vel.fit(X, y)
# calculate trend
trend_vel = model_vel.predict(X_vel)
fit_ax.plot(trend)
fit_ax.set_title("Trend fitted by linear regression")

plt.tight_layout()

# %%
bxl_5['count'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
bxl_5['vel'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
bxl_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2156506 entries, 2021-03-13 11:35:00 to 2021-06-05 23:55:00
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   street_id         float64
#  1   count             int64
#  2   vel               float64
#  3   time_taken(mins)  int64
#  4   date              object
#  5   month             float64
#  6   week              float64
#  7   time              object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 148.1+ MB

# %%
import seaborn as sns
pair = bxl_5[['count', 'vel', 'month', 'week']]
sns.pairplot(pair)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6), facecolor='white')

plt.subplot(1, 2, 1)

ax = sns.barplot(x = bxl_5['week'], y = bxl_5['count'], palette = 'spring') # creating a bargraph
ax.set_xlabel(xlabel = 'week', fontsize = 9)
ax.set_ylabel(ylabel = 'number of trucks', fontsize = 9)

plt.subplot(1, 2, 2)

ax = sns.barplot(x = bxl_5['week'], y = bxl_5['vel'], palette = 'spring') # creating a bargraph
ax.set_xlabel(xlabel = 'week', fontsize = 9)
ax.set_ylabel(ylabel = 'velocity', fontsize = 9)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6), facecolor='white')

plt.subplot(1, 2, 1) # row 1, col 2 index 1
ax = sns.barplot(x = bxl_5['month'], y = bxl_5['count'], palette = 'spring') # creating a bargraph
ax.set_xlabel(xlabel = 'month', fontsize = 9)
ax.set_ylabel(ylabel = 'number of trucks', fontsize = 9)

plt.subplot(1, 2, 2) # index 2

ax = sns.barplot(x = bxl_5['month'], y = bxl_5['vel'], palette = 'spring') # creating a bargraph
ax.set_xlabel(xlabel = 'month', fontsize = 9)
ax.set_ylabel(ylabel = 'velocity', fontsize = 9)
plt.show()

# %%
df_bxl_sum = bxl_5.sort_values(by=['datetime']).groupby(['datetime']).agg({'count':'sum'}).reset_index()
df_bxl_sum.head(3)
# Out:
#              datetime  count
# 0 2021-03-13 11:35:00     51
# 1 2021-03-13 11:40:00     51
# 2 2021-03-13 11:45:00     59

# %%
import seaborn as sns
sns.distplot(df_bxl_sum['count'], hist=False, kde=True, bins= 200, color = 'blue',hist_kws={'edgecolor':'black'})
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='count', ylabel='Density'>

# %%
import matplotlib.pyplot as plt
bxl_5.sort_values(by=['datetime']).groupby(['datetime']).agg({'count':'sum'}).plot(figsize=(10,5), color = 'red', rot=45, title='count of truck - trend -BXL')
plt.show()

# %%
bxl_5.sort_values(by=['datetime']).groupby(['datetime']).agg({'vel':'sum'}).plot(figsize=(10,5), color = 'red', rot=45, title='velocity of trucks - trend - BXL')
plt.show()

# %%
bxl_5.sort_values(by=['time']).groupby(['time']).agg({'count':'sum'}).plot(figsize=(10,5), color = 'red', rot=45, title='total truck traffic on daily basis')
plt.show()

# %%
bxl_5.sort_values(by=['time']).groupby(['time']).agg({'vel':'mean'}).plot(figsize=(10,5), color = 'red', rot=45, title='average velocity of trucks in a day')
plt.show()

# %%
bxl_5.sort_values(by=['week']).groupby(['week']).agg({'vel':'mean'}).plot(figsize=(10,5), color = 'red', rot=45, title='velocity trend of truck - per week - BXL')
plt.show()

# %%
bxl_5.sort_values(by=['week']).groupby(['week']).agg({'count':'sum'}).plot(figsize=(10,5), color = 'red', rot=45, title='total traffic trend of truck - per week - BXL')
plt.show()

# %%
bxl_vel_sum = bxl_5.sort_values(by=['datetime']).groupby(['datetime']).agg({'vel':'sum'}).reset_index()
sns.distplot(bxl_vel_sum['vel'], hist=False, kde=True, bins= 200, color = 'blue',hist_kws={'edgecolor':'black'})
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='vel', ylabel='Density'>

# %%
bxl_sum = bxl_5.sort_values(by=['datetime']).groupby(['datetime']).agg({'count':'sum'}).reset_index()
bxl_sum['time'] = pd.to_datetime(bxl_sum['datetime']).dt.time
bxl_sum['DayOfWeek'] = pd.to_datetime(bxl_sum['datetime']).dt.dayofweek

# %%
bxl_working = bxl_sum[bxl_sum['DayOfWeek'] < 5]
bxl_saturday = bxl_sum[bxl_sum['DayOfWeek'] == 5]
bxl_sunday = bxl_sum[bxl_sum['DayOfWeek'] == 6]

# %%
bxlvel_sum = bxl_5.sort_values(by=['datetime']).groupby(['datetime']).agg({'vel':'mean'}).reset_index()
bxlvel_sum['time'] = pd.to_datetime(bxlvel_sum['datetime']).dt.time
bxlvel_sum['DayOfWeek'] = pd.to_datetime(bxlvel_sum['datetime']).dt.dayofweek

# %%
bxlvel_working = bxlvel_sum[bxlvel_sum['DayOfWeek'] < 5]
bxlvel_saturday = bxlvel_sum[bxlvel_sum['DayOfWeek'] == 5]
bxlvel_sunday = bxlvel_sum[bxl_sum['DayOfWeek'] == 6]

# %%
sns.distplot(bxl_vel_sum['vel'], hist=False, kde=True, bins= 200, color = 'blue',hist_kws={'edgecolor':'black'})
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='vel', ylabel='Density'>

# %%
bxl_working.sort_values(by=['DayOfWeek']).groupby(['DayOfWeek']).agg({'count':'mean'}).plot(figsize=(10,5), color = 'red', rot=45, title='Belgium')
plt.show()

# %%
bxl_saturday.sort_values(by=['time']).groupby(['time']).agg({'count':'mean'}).plot(figsize=(10,5), color = 'red', rot=45, title='Belgium')
plt.show()

# %%
bxl_sunday.sort_values(by=['time']).groupby(['time']).agg({'count':'mean'}).plot(figsize=(10,5), color = 'red', rot=45, title='Belgium')
plt.show()

# %%
bxl_working.sort_values(by=['time']).groupby(['time']).agg({'count':'mean'}).plot(figsize=(10,5), color = 'red', rot=45, title='Belgium')
plt.show()

# %%
bxlvel_working.sort_values(by=['time']).groupby(['time']).agg({'vel':'mean'}).plot(figsize=(10,5), color = 'red', rot=45, title='Belgium')
plt.show()

# %%
bxlvel_saturday.sort_values(by=['time']).groupby(['time']).agg({'vel':'mean'}).plot(figsize=(10,5), color = 'red', rot=45, title='Belgium')
plt.show()

# %%
bxlvel_sunday.sort_values(by=['time']).groupby(['time']).agg({'vel':'mean'}).plot(figsize=(10,5), color = 'red', rot=45, title='Belgium')
plt.show()
